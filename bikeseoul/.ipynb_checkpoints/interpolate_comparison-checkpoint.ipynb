# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train
# Out:
#             date  precipitation  temp_mean  temp_highest  temp_lowest  PM10  \
# 0     2018-01-01            NaN       -1.3           3.8         -5.1   NaN
# 1     2018-01-02            NaN       -1.8           1.8         -4.3   NaN
# 2     2018-01-03            NaN       -4.7          -0.4         -7.1   NaN
# 3     2018-01-04            NaN       -4.7          -0.7         -8.7   NaN
# 4     2018-01-05            NaN       -3.0           1.6         -5.6   NaN
# ...          ...            ...        ...           ...          ...   ...
# 1090  2020-12-27            0.0        5.8          10.0          1.4   NaN
# 1091  2020-12-28            1.3        6.7          11.4          4.2   NaN
# 1092  2020-12-29            0.2        0.1           4.3         -6.2   NaN
# 1093  2020-12-30            NaN      -10.9          -6.2        -12.9   NaN
# 1094  2020-12-31            0.0       -8.9          -5.0        -12.9   NaN
#
# ...

# %%
#‘linear’: Ignore the index and treat the values as equally spaced.
ip_linear = train.interpolate(method = 'linear') #slinear도 같은 결과
ip_pad = train.interpolate(method = 'pad') #"nearest와 동일"

# spline method -> 상세한 내용에 대해서는 좀 더 필요(결과는 가장 비슷하게 나옴)
# 단, 초미세먼지 데이터에서 음수가 나온다는 부분은 조금 아쉽
# order 는 함수의 차수를 의미 즉 여기서는 4차 함수 
ip_spline = train.interpolate(method='spline', order = 4)

# %%
# interpolation result
plt.figure(figsize = (10,10))

plt.subplot(2,2,1)
plt.title('linear interpolation')
sns.lineplot(data = ip_linear['PM10'][78:100])

plt.subplot(2,2,2)
plt.title('pad interpolation')
sns.lineplot(data = ip_pad['PM10'][78:100])

plt.subplot(2,2,3)
plt.title('spline interpolation')
sns.lineplot(data = ip_spline['PM10'][78:100])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [36], in <cell line: 6>()
#       4 plt.subplot(2,2,1)
#       5 plt.title('linear interpolation')
# ----> 6 sns.lineplot(data = ip_linear['PM10'][78:100])
#       8 plt.subplot(2,2,2)
#       9 plt.title('pad interpolation')
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
# ...

# %%
# model 학습(linear interpolation)

linear_train = train
linear_train
# Out:
#             date  precipitation  temp_mean  temp_highest  temp_lowest  PM10  \
# 0     2018-01-01            NaN       -1.3           3.8         -5.1   NaN
# 1     2018-01-02            NaN       -1.8           1.8         -4.3   NaN
# 2     2018-01-03            NaN       -4.7          -0.4         -7.1   NaN
# 3     2018-01-04            NaN       -4.7          -0.7         -8.7   NaN
# 4     2018-01-05            NaN       -3.0           1.6         -5.6   NaN
# ...          ...            ...        ...           ...          ...   ...
# 1090  2020-12-27            0.0        5.8          10.0          1.4   NaN
# 1091  2020-12-28            1.3        6.7          11.4          4.2   NaN
# 1092  2020-12-29            0.2        0.1           4.3         -6.2   NaN
# 1093  2020-12-30            NaN      -10.9          -6.2        -12.9   NaN
# 1094  2020-12-31            0.0       -8.9          -5.0        -12.9   NaN
#
# ...

# %%
linear_train.isnull().sum()
# Out:
# date                0
# precipitation     678
# temp_mean           0
# temp_highest        0
# temp_lowest         0
# PM10             1073
# PM2.5              68
# humidity            0
# sunshine_sum        5
# sunshine_rate       0
# wind_mean           0
# wind_max            0
# rental              0
# dtype: int64

# %%
# model 학습(pad interpolation)

# %%
# model 학습(spline interpolation)
